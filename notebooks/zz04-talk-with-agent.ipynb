# %%
from letta_client import Letta

client = Letta(base_url="http://localhost:8283")

# %%
agent_id = "agent-d92f2e63-7a62-4b34-8ed8-fca3a5bbe20c"
agent = client.agents.retrieve(
    agent_id=agent_id,
)

# %%
from utils.message_parser import chat_and_print, pretty_print_messages

# Use our new chat_and_print wrapper that natively checks memory differences!
response = chat_and_print(
    client=client,
    agent_id=agent.id,
    input="你好，我是张伟"
)

# %%
# If we want to see the whole historical log properly:
# Get all messages
history = list(client.agents.messages.list(agent_id=agent_id))

# the Letta return from list() usually is naturally reversed (oldest first or newest first). Let's print the last 5
pretty_print_messages(history[-5:])

# %%
# Let's prompt the agent to explicitly use a tool (like update core memory) so we can see how the parser displays the diff!
response = chat_and_print(
    client=client,
    agent_id=agent.id,
    input="请记住，我最喜欢的颜色是深蓝色，我是一个程序员。把这个写进你的核心记忆里。"
)
