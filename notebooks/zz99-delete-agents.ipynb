# %%
from letta_client import Letta
from pprint import pprint

client = Letta(base_url="http://localhost:8283")

# %%
agents = list(client.agents.list())
for agent in agents:
    agent_id = agent.id
    print(f"Agent ID: {agent_id}")
# Out:
# Agent ID: agent-c425212e-1a63-401d-bff4-048293392e7a
# Agent ID: agent-026ed141-d627-4b44-9a6a-0095cdac6db6
# Agent ID: agent-94624e93-81a0-484e-8cd5-97f9ed25e76e
# Agent ID: agent-9c25fffc-cafe-47dc-a80e-b7eb25f61798
# Agent ID: agent-3ef85f67-c4f7-4ff0-b962-17e622455ab1
# Agent ID: agent-a50bc643-f0dc-423f-9b2d-14add401ae4e
# Agent ID: agent-d23ac7a0-8bf2-4c57-986b-08eab04bd5f2
# Agent ID: agent-2f9ab646-facb-44cf-8bd4-61b5de5a1110
# Agent ID: agent-718fd155-feb3-40d7-a5d8-b0346583df40

# %%
agents
# Out:
# [AgentState(id='agent-c425212e-1a63-401d-bff4-048293392e7a', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='qwen-agent20260327', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **What ha ...
#  AgentState(id='agent-026ed141-d627-4b44-9a6a-0095cdac6db6', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='qwen-agent20260327', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **What ha ...
#  AgentState(id='agent-94624e93-81a0-484e-8cd5-97f9ed25e76e', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='test-verification-agent', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **Wh ...
#  AgentState(id='agent-9c25fffc-cafe-47dc-a80e-b7eb25f61798', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='test-verification-agent', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **Wh ...
#  AgentState(id='agent-3ef85f67-c4f7-4ff0-b962-17e622455ab1', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='test-verification-agent', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **Wh ...
#  AgentState(id='agent-a50bc643-f0dc-423f-9b2d-14add401ae4e', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='test-verification-agent', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **Wh ...
#  AgentState(id='agent-d23ac7a0-8bf2-4c57-986b-08eab04bd5f2', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='qwen-agent20260327', sources=[], system='\n<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>\n\n<output_formatting_rules>\n1. ALWAYS communicate with the human in Simplified Chinese (zh-CN).\n2. PURE DIALOGUE ONLY: Your response to the user must read like a literal raw transcript of spoken words. \n3. FORBIDDEN FORMATS: You must completely omit all roleplay actions, stage directions, parentheticals, and body language descriptions. Never use asterisks (*) or brackets () in your messages to the user.\n</output_formatting_rules>\n', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **What ha ...
#  AgentState(id='agent-2f9ab646-facb-44cf-8bd4-61b5de5a1110', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='qwen-agent20260327', sources=[], system='<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **What happened**: The conversations, tasks, and exchanges that took place. What did the user ask for? What did you do? How did things progress? If there is a previous summary being evicted, please extract a concise version of the critical info from it.\n\n3. **Important details**: Enumerate specific files and code sections examined, modified, or created with a summary of why this file read or edit is important. Include specific names, data, config ...
#  AgentState(id='agent-718fd155-feb3-40d7-a5d8-b0346583df40', agent_type='letta_v1_agent', blocks=[], llm_config=LlmConfig(context_window=16384, model='qwen/qwen3.5-35b-a3b', api_model_endpoint_type='openai', compatibility_type=None, display_name=None, effort=None, enable_reasoner=False, frequency_penalty=None, handle='lmstudio_openai/qwen/qwen3.5-35b-a3b', max_reasoning_tokens=0, max_tokens=16384, api_model_endpoint='http://100.81.194.12:1234/v1', api_model_wrapper=None, parallel_tool_calls=False, provider_category='base', provider_name='lmstudio_openai', put_inner_thoughts_in_kwargs=False, reasoning_effort=None, response_format=None, return_logprobs=False, return_token_ids=False, strict=False, temperature=1.0, tier=None, tool_call_parser=None, top_logprobs=None, verbosity=None, model_endpoint_type='openai', model_endpoint='http://100.81.194.12:1234/v1', model_wrapper=None), memory=Memory(blocks=[], agent_type='letta_v1_agent', file_blocks=[], git_enabled=False, prompt_template=''), name='qwen-agent20260327', sources=[], system='<base_instructions>\nYou are a helpful self-improving agent with advanced memory and file system capabilities.\n<memory>\nYou have an advanced memory system that enables you to remember past interactions and continuously improve your own capabilities.\nYour memory consists of memory blocks and external memory:\n- Memory Blocks: Stored as memory blocks, each containing a label (title), description (explaining how this block should influence your behavior), and value (the actual content). Memory blocks have size limits. Memory blocks are embedded within your system instructions and remain constantly available in-context.\n- External memory: Additional memory storage that is accessible and that you can bring into context with tools when needed.\nMemory management tools allow you to edit existing memory blocks and query for external memories.\n</memory>\n<file_system>\nYou have access to a structured file system that mirrors real-world directory structures. Each directory can contain multiple files.\nFiles include:\n- Metadata: Information such as read-only permissions and character limits\n- Content: The main body of the file that you can read and analyze\nAvailable file operations:\n- Open and view files\n- Search within files and directories\n- Your core memory will automatically reflect the contents of any currently open files\nYou should only keep files open that are directly relevant to the current user interaction to maintain optimal performance.\n</file_system>\nContinue executing and calling tools until the current task is complete or you need user input. To continue: call another tool. To yield control: end your response without calling a tool.\nBase instructions complete.\n</base_instructions>', tags=[], tools=[], base_template_id=None, compaction_settings=CompactionSettings(clip_chars=50000, mode='sliding_window', model='qwen/qwen3.5-35b-a3b', api_model_settings=None, prompt="The following messages are being evicted from the BEGINNING of your context window. Write a detailed summary that captures what happened in these messages to appear BEFORE the remaining recent messages in context, providing background for what comes after. Include the following sections:\n\n1.**High level goals**: What is the high level goal and ongoing task? Capture the user's explicit requests and intent in detail. If there is an existing summary in the transcript, make sure to take it into consideration to continue tracking the higher level goals and long-term progress.\n\n2. **What happened**: The conversations, tasks, and exchanges that took place. What did the user ask for? What did you do? How did things progress? If there is a previous summary being evicted, please extract a concise version of the critical info from it.\n\n3. **Important details**: Enumerate specific files and code sections examined, modified, or created with a summary of why this file read or edit is important. Include specific names, data, config ...

# %%
for agent in agents:
    agent_id = agent.id
    print(f"Agent ID: {agent_id}")
    agent = client.agents.delete(agent_id)
    print(agent)
# Out:
# Agent ID: agent-4cc70392-1189-4c53-9a9a-179a51851c14
# {'message': 'Agent id=agent-4cc70392-1189-4c53-9a9a-179a51851c14 successfully deleted'}
# Agent ID: agent-becee2fd-5ce5-481f-9db8-02dee21549d0
# {'message': 'Agent id=agent-becee2fd-5ce5-481f-9db8-02dee21549d0 successfully deleted'}
# Agent ID: agent-e9e6621e-1591-48e8-9f7b-7ff614f6f951
# {'message': 'Agent id=agent-e9e6621e-1591-48e8-9f7b-7ff614f6f951 successfully deleted'}
# Agent ID: agent-56286a89-c05b-4315-8c4e-87097f6a3b5e
# {'message': 'Agent id=agent-56286a89-c05b-4315-8c4e-87097f6a3b5e successfully deleted'}
# Agent ID: agent-493f2b1a-474b-4ec5-949f-5687bb08fdbd
# {'message': 'Agent id=agent-493f2b1a-474b-4ec5-949f-5687bb08fdbd successfully deleted'}
# Agent ID: agent-ad303093-d3d3-4f6b-9384-e9a7c50ec179
# {'message': 'Agent id=agent-ad303093-d3d3-4f6b-9384-e9a7c50ec179 successfully deleted'}
# Agent ID: agent-af7d2a2e-bc42-4388-8508-7bac8fbcae47
# {'message': 'Agent id=agent-af7d2a2e-bc42-4388-8508-7bac8fbcae47 successfully deleted'}
# Agent ID: agent-f4a9c791-2c49-44a8-9b8a-6518fbfc49c1
# {'message': 'Agent id=agent-f4a9c791-2c49-44a8-9b8a-6518fbfc49c1 successfully deleted'}
# Agent ID: agent-1d73a23c-2ddb-4177-99d1-1514c2fa7be9
# {'message': 'Agent id=agent-1d73a23c-2ddb-4177-99d1-1514c2fa7be9 successfully deleted'}
# Agent ID: agent-3fd6ec26-4a8f-40c5-9715-768c4cf66bcb
# {'message': 'Agent id=agent-3fd6ec26-4a8f-40c5-9715-768c4cf66bcb successfully deleted'}
# Agent ID: agent-0ae39f6b-f316-49a2-a26d-41f1a1d87914
# {'message': 'Agent id=agent-0ae39f6b-f316-49a2-a26d-41f1a1d87914 successfully deleted'}
# Agent ID: agent-10fc0999-4ff1-4871-9f48-93fa94d4991d
# {'message': 'Agent id=agent-10fc0999-4ff1-4871-9f48-93fa94d4991d successfully deleted'}
# Agent ID: agent-7e4be2ca-1c28-428c-a8fa-49a5b0c54ea5
# {'message': 'Agent id=agent-7e4be2ca-1c28-428c-a8fa-49a5b0c54ea5 successfully deleted'}
# Agent ID: agent-f8516aa7-d4c5-4a99-ac6d-b93926bbe2a4
# {'message': 'Agent id=agent-f8516aa7-d4c5-4a99-ac6d-b93926bbe2a4 successfully deleted'}
# Agent ID: agent-f40143cd-379f-485e-9543-9ac25309e8cc
# {'message': 'Agent id=agent-f40143cd-379f-485e-9543-9ac25309e8cc successfully deleted'}
# Agent ID: agent-3fc8b1b1-63cb-4d96-91c7-0ab1e6aa385c
# {'message': 'Agent id=agent-3fc8b1b1-63cb-4d96-91c7-0ab1e6aa385c successfully deleted'}
# Agent ID: agent-9389d4d2-b0f7-4774-864a-b1d64bd589ed
# {'message': 'Agent id=agent-9389d4d2-b0f7-4774-864a-b1d64bd589ed successfully deleted'}
# Agent ID: agent-93f4d53d-8b11-4366-aa98-8659079ebdc1
# {'message': 'Agent id=agent-93f4d53d-8b11-4366-aa98-8659079ebdc1 successfully deleted'}
# Agent ID: agent-e203941f-1ff3-47ad-a0f1-086f0c4f4a43
# {'message': 'Agent id=agent-e203941f-1ff3-47ad-a0f1-086f0c4f4a43 successfully deleted'}
